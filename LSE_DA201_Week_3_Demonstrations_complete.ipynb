# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # DA201: Data Analytics Using Python

# %% [markdown]
# ## Week 3: Data wrangling with Pandas

# %% [markdown]
# The focus this week is on data ingestion and data wrangling.
#
# This is your notebook. You will use this notebook to follow along with the demonstrations throughout the week. Use it to test ideas, and explore what is possible. The hands-on experience of writing your own code will accelarate your learning!
#
# Learn about using your Jupyter Notebook here: https://jupyter-notebook.readthedocs.io/en/latest/ui_components.html.

# %% [markdown]
# ### 3.1 Wrangling data with Pandas

# %%
# Create a dictionary for cars and motorcycles
cars = {'Make': ['Volkswagen (VW)', 'Toyota', 'Honda', 'BMW'],
        'Car models': ['Polo, T-Cross, Tiguan, Touareg','Agya, Corolla, Rav4, Land Cruiser',
                       'Brio, Jazz, HRV, CRV','BMW1, BMW2, BMW3, BMW4']
       }

motorcycles = {'Make': ['Volkswagen (VW)', 'Toyota', 'Honda', 'BMW'],
        'Motorcycle models': [' ',' ','Shine, Activa, Comfort Travel, Adventure Sport',
                              'Sport, Roadster, Heritage, Adventure']
       }

# %%
import pandas as pd

# %%
cars_table = pd.DataFrame(cars)

# %%
cars_table
# Out:
#               Make                         Car models
# 0  Volkswagen (VW)     Polo, T-Cross, Tiguan, Touareg
# 1           Toyota  Agya, Corolla, Rav4, Land Cruiser
# 2            Honda               Brio, Jazz, HRV, CRV
# 3              BMW             BMW1, BMW2, BMW3, BMW4

# %% [markdown]
# #

# %%
motorcycles_table = pd.DataFrame(motorcycles)

# %%
motorcycles_table
# Out:
#               Make                               Motorcycle models
# 0  Volkswagen (VW)
# 1           Toyota
# 2            Honda  Shine, Activa, Comfort Travel, Adventure Sport
# 3              BMW            Sport, Roadster, Heritage, Adventure

# %%
# Create a dictionary for cars and motorcycles
cars_ok = {'Volkswagen (VW)':['Polo', 'T-Cross', 'Tiguan', 'Touareg'],
        'Toyota':['Agya', 'Corolla', 'Rav4', 'Land Cruiser'],
        'Honda':['Brio', 'Jazz', 'HRV', 'CRV'],
        'BMW':['BMW1', 'BMW2', 'BMW3', 'BMW4']}

motorcycles_ok = {'Volkswagen (VW)': [' ', ' ', ' ', ' '],
               'Toyota':[' ', ' ', ' ', ' '],
               'Honda':['Shine', 'Activa', 'Comfort Travel', 'Adventure Sport'],
               'BMW': ['Sport', 'Roadster', 'Heritage', 'Adventure']
              }

# %%
cars_table = pd.DataFrame(cars_ok, columns=('Volkswagen (VW)','Toyota','Honda','BMW'),index=(0,1,2,3))

# %%
cars_table
# Out:
#   Volkswagen (VW)        Toyota Honda   BMW
# 0            Polo          Agya  Brio  BMW1
# 1         T-Cross       Corolla  Jazz  BMW2
# 2          Tiguan          Rav4   HRV  BMW3
# 3         Touareg  Land Cruiser   CRV  BMW4

# %%
motorcycles_table = pd.DataFrame(motorcycles_ok, columns=('Volkswagen (VW)','Toyota','Honda','BMW'),index=(4,5,6,7))

# %%
motorcycles_table
# Out:
#   Volkswagen (VW) Toyota            Honda        BMW
# 4                                   Shine      Sport
# 5                                  Activa   Roadster
# 6                          Comfort Travel   Heritage
# 7                         Adventure Sport  Adventure

# %%
# Concatenate the two DataFrames.
products = pd.concat([cars_table, motorcycles_table])

# %%
products
# Out:
#   Volkswagen (VW)        Toyota            Honda        BMW
# 0            Polo          Agya             Brio       BMW1
# 1         T-Cross       Corolla             Jazz       BMW2
# 2          Tiguan          Rav4              HRV       BMW3
# 3         Touareg  Land Cruiser              CRV       BMW4
# 4                                          Shine      Sport
# 5                                         Activa   Roadster
# 6                                 Comfort Travel   Heritage
# 7                                Adventure Sport  Adventure

# %%
# Create cars_2 DataFrame.
cars_2 = pd.DataFrame({'VW': ['Polo', 'T-Cross', 'Tiguan', 'Toureg'],
                       'Toyota': ['Agya', 'Corolla', 'Rav4', 'Land Cruiser'],
                       'Honda': ['Brio', 'Jazz', 'HRV', 'CRV'], 
                       'BMW': ['BMW1', 'BMW2', 'BMW3', 'BMW4']},
                     index=['car1', 'car2', 'car3', 'car4'])


# Create motorcycles_2 DataFrame.
motorcycles_2 = pd.DataFrame({'VW': ['-', '-', '-', '-'],
                              'Toyota': ['-', '-', '-', '-'],
                              'Honda': ['Shine', 'Activa', 'Comfort Travel', 
                                        'Adventure Sport'],
                              'BMW': ['Sport', 'Roadster', 'Heritage', 'Adventure']},
                            index=['mcycle1', 'mcycle2', 'mcycle3', 'mcycle4'])


# Concatenate the two DataFrames.
products_2 = pd.concat([cars_2, motorcycles_2])

# View the DataFrame.
products_2
# Out:
#               VW        Toyota            Honda        BMW
# car1        Polo          Agya             Brio       BMW1
# car2     T-Cross       Corolla             Jazz       BMW2
# car3      Tiguan          Rav4              HRV       BMW3
# car4      Toureg  Land Cruiser              CRV       BMW4
# mcycle1        -             -            Shine      Sport
# mcycle2        -             -           Activa   Roadster
# mcycle3        -             -   Comfort Travel   Heritage
# mcycle4        -             -  Adventure Sport  Adventure

# %%
# Concatenate the two DataFrames per columns instead of rows
products_2 = pd.concat([cars_2, motorcycles_2],axis=0)

# %%
products_2
# Out:
#               VW        Toyota            Honda        BMW
# car1        Polo          Agya             Brio       BMW1
# car2     T-Cross       Corolla             Jazz       BMW2
# car3      Tiguan          Rav4              HRV       BMW3
# car4      Toureg  Land Cruiser              CRV       BMW4
# mcycle1        -             -            Shine      Sport
# mcycle2        -             -           Activa   Roadster
# mcycle3        -             -   Comfort Travel   Heritage
# mcycle4        -             -  Adventure Sport  Adventure

# %%
products_3 = pd.concat([cars_2, motorcycles_2],axis=1)

# %%
products_3
# Out:
#               VW        Toyota Honda   BMW   VW Toyota            Honda  \
# car1        Polo          Agya  Brio  BMW1  NaN    NaN              NaN
# car2     T-Cross       Corolla  Jazz  BMW2  NaN    NaN              NaN
# car3      Tiguan          Rav4   HRV  BMW3  NaN    NaN              NaN
# car4      Toureg  Land Cruiser   CRV  BMW4  NaN    NaN              NaN
# mcycle1      NaN           NaN   NaN   NaN    -      -            Shine
# mcycle2      NaN           NaN   NaN   NaN    -      -           Activa
# mcycle3      NaN           NaN   NaN   NaN    -      -   Comfort Travel
# mcycle4      NaN           NaN   NaN   NaN    -      -  Adventure Sport
#
#                BMW
# car1           NaN
# car2           NaN
# car3           NaN
# car4           NaN
# mcycle1      Sport
# mcycle2   Roadster
# mcycle3   Heritage
# mcycle4  Adventure

# %%
# Import Pandas. 
import pandas as pd

# Read the csv file.
classlist_a = pd.read_csv('classlist_a.csv')

# %%
# Determine shape of classlist.
print(classlist_a.shape)
# Out:
# (145, 5)

# %%
classlist_a
# Out:
#      Student number    Surname Initials  Final mark Class
# 0          15476227     AFONSO        L       47.72     E
# 1          15311279   ALBERTYN    F J H       57.52     A
# 2          15637913  ALEXANDER        L       90.68     E
# 3          15124150        BAM      A J       56.43     E
# 4          15829626     BARROW      S B       79.64     E
# ..              ...        ...      ...         ...   ...
# 140        15198162    WEGENER      A M       48.83     E
# 141        15618935  WEIGHTMAN      C J       88.33     A
# 142        15715396   WILLIAMS        N       75.66     E
# 143        15849390      YOUNG      V A       88.05     E
# 144        15897184    ZONDAGH        L       59.10     E
#
# [145 rows x 5 columns]

# %%
classlist_b = pd.read_csv('classlist_b.csv')

# %%
classlist_b
# Out:
#      Student number    Surname Initials  Final mark Class
# 0          16138201     ATWOOD       BJ       73.27     E
# 1          16007530     BASSON       WC       44.18     E
# 2          16764773      BESSA       LW       49.10     E
# 3          15991733     BESTER        C       67.44     A
# 4          16127447       BLOM       PJ       42.52     A
# ..              ...        ...      ...         ...   ...
# 121        16037804    VIVIERS       SF       59.31     A
# 122        16239369    WATKINS       TL       76.71     A
# 123        16070356  WILKINSON       GN       62.04     E
# 124        16083814       WISE       EA       71.82     E
# 125        16324773      ZONDI       WP       74.46     A
#
# [126 rows x 5 columns]

# %%
classlist_c = pd.read_csv('classlist_c.csv')

# %%
classlist_c
# Out:
#      Student number     Surname    Initials  Final mark Class
# 0          15849376   ADENDORFF  K                76.50     E
# 1          15805751    AUDITORE  L                64.25     E
# 2          16160045       BAARD  JC               51.25     E
# 3          16488547  BADENHORST  MJ               68.00     A
# 4          16586263      BASSON  J                57.75     A
# ..              ...         ...         ...         ...   ...
# 180        16501373    WILCKENS  M                58.25     A
# 181        16085868      WILMOT  J                74.00     E
# 182        16542878       WOODS  MJ               45.50     E
# 183        16721047    WURDEMAN  BM               64.00     A
# 184        16782879        ZUMA  MC               64.50     A
#
# [185 rows x 5 columns]

# %%
classlist_d = pd.read_csv('classlist_d.csv')

# %%
classlist_d
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15793648  ABRAHAMS                        B                   48
# 1          17483638  ACKERMANN                       E                   45
# 2          16564499  ALBERTUS                        S                   57
# 3          17176654  ALWARD                          F                    0
# 4          17006414  ANDERSEN                        M                   28
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC                  93
# 215        14955849  WIJNBERG                        JM                  47
# 216        17140293  WILLIAMS                        CA                  43
# 217        16771354  WOLHUTER                        J                   76
# 218        17094607  ZINN                            A                   74
#
#     Class
# 0       E
# 1       E
# 2       E
# ...

# %%
classlist_ab = pd.concat([classlist_a,classlist_b])

# %%
classlist_ab.shape
# Out:
# (271, 5)

# %%
classlist_ab
# Out:
#      Student number    Surname Initials  Final mark Class
# 0          15476227     AFONSO        L       47.72     E
# 1          15311279   ALBERTYN    F J H       57.52     A
# 2          15637913  ALEXANDER        L       90.68     E
# 3          15124150        BAM      A J       56.43     E
# 4          15829626     BARROW      S B       79.64     E
# ..              ...        ...      ...         ...   ...
# 121        16037804    VIVIERS       SF       59.31     A
# 122        16239369    WATKINS       TL       76.71     A
# 123        16070356  WILKINSON       GN       62.04     E
# 124        16083814       WISE       EA       71.82     E
# 125        16324773      ZONDI       WP       74.46     A
#
# [271 rows x 5 columns]

# %%
classlist_cd = pd.concat([classlist_c,classlist_d])

# %%
classlist_cd.shape
# Out:
# (404, 5)

# %%
classlist_cd
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15849376                       ADENDORFF  K                76.50
# 1          15805751                        AUDITORE  L                64.25
# 2          16160045                           BAARD  JC               51.25
# 3          16488547                      BADENHORST  MJ               68.00
# 4          16586263                          BASSON  J                57.75
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class
# 0       E
# 1       E
# 2       E
# ...

# %%
classlist_final = pd.concat([classlist_ab,classlist_cd])

# %%
classlist_final.shape
# Out:
# (675, 5)

# %%
classlist_final
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class
# 0       E
# 1       A
# 2       E
# ...

# %%
# concat all of them method 2

classlist_final2 = pd.concat([classlist_a, classlist_b, classlist_c, classlist_d])

# %%
classlist_final2
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class
# 0       E
# 1       A
# 2       E
# ...

# %%
classlist_final2_sort = classlist_final2.sort_values(by='Surname')

# %%
classlist_final2_sort
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15793648  ABRAHAMS                        B                48.00
# 1          17483638  ACKERMANN                       E                45.00
# 0          15849376                       ADENDORFF  K                76.50
# 0          15476227                          AFONSO           L       47.72
# 2          16564499  ALBERTUS                        S                57.00
# ..              ...                             ...         ...         ...
# 143        15849390                           YOUNG         V A       88.05
# 218        17094607  ZINN                            A                74.00
# 144        15897184                         ZONDAGH           L       59.10
# 125        16324773                           ZONDI          WP       74.46
# 184        16782879                            ZUMA  MC               64.50
#
#     Class
# 0       E
# 1       E
# 0       E
# ...

# %%
classlist_final3_sort = classlist_final2.sort_values(by='Student number')

# %%
classlist_final3_sort
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 37         13418041                          FOURIE         R B       62.58
# 45         14172682                          HEUNIS           W       62.25
# 108        14438321                       SCHAFFERS         I C        0.00
# 115        14558289                          MILLER  N                92.00
# 91         14574462                        LEYGONIE  IR               54.00
# ..              ...                             ...         ...         ...
# 111        17465133  MBATHA                          PC               25.00
# 1          17483638  ACKERMANN                       E                45.00
# 178        17624258  STOFBERG                        Z                42.00
# 173        17725070  STAMP                           JR               86.00
# 128        18376673  NEWTON                          KA               83.00
#
#     Class
# 37      E
# 45      A
# 108     E
# ...

# %%
# If we apply sorted

sorted(classlist_final2)
# Out:
# ['Class', 'Final mark', 'Initials', 'Student number', 'Surname']

# %%
sorted(classlist_final2.columns)
# Out:
# ['Class', 'Final mark', 'Initials', 'Student number', 'Surname']

# %%
sorted(classlist_final2.columns, reverse=True)
# Out:
# ['Surname', 'Student number', 'Initials', 'Final mark', 'Class']

# %% [markdown]
# 3.1.3 Introduction to merge()

# %%
# Import Pandas. 
import pandas as pd

# Create a DataFrame.
cars_3 = pd.DataFrame({'VW': ['Polo', 'T-Cross', 'Tiguan', 'Toureg'],
                    'Toyota': ['Agya', 'Corolla', 'Rav4', 'Land Cruiser'],
                   'Honda': ['Brio', 'Jazz', 'HRV', 'CRV'], 
                   'BMW': ['BMW1', 'BMW2', 'BMW3', 'BMW4']}, 
                   index=[0, 1, 2, 3])

# View the DataFrame.
cars_3
# Out:
#         VW        Toyota Honda   BMW
# 0     Polo          Agya  Brio  BMW1
# 1  T-Cross       Corolla  Jazz  BMW2
# 2   Tiguan          Rav4   HRV  BMW3
# 3   Toureg  Land Cruiser   CRV  BMW4

# %%
# Create a DataFrame.
motorcycles_3 = pd.DataFrame({'VW': ['-', '-', '-', '-'],
               'Toyota': ['-', '-', '-', '-'],
               'Honda': ['Shine', 'Activa', 'Comfort Travel',
'Adventure Sport'], 
               'BMW': ['Sport', 'Roadster', 'Heritage',
'Adventure']}, 
               index=[0, 1, 2, 3])

# View the DataFrame.
motorcycles_3
# Out:
#   VW Toyota            Honda        BMW
# 0  -      -            Shine      Sport
# 1  -      -           Activa   Roadster
# 2  -      -   Comfort Travel   Heritage
# 3  -      -  Adventure Sport  Adventure

# %%
products3 = pd.merge(cars_3,motorcycles_3)

# %%
print(products3)
# Out:
# Empty DataFrame
# Columns: [VW, Toyota, Honda, BMW]
# Index: []

# %%
# Import Pandas.
import pandas as pd

# Import the CSV files.
classlist_a = pd.read_csv('classlist_a.csv')
classlist_b = pd.read_csv('classlist_b.csv')
classlist_c = pd.read_csv('classlist_c.csv')
classlist_d = pd.read_csv('classlist_d.csv')

# Concatenate classlists a and b; and c and d.
classlist_ab = pd.concat([classlist_a, classlist_b])
classlist_cd = pd.concat([classlist_c, classlist_d])

# View DataFrames.
print(classlist_ab.shape)
print(classlist_cd.shape)
# Out:
# (271, 5)
# (404, 5)

# %%
# Merge class lists ab and cd.
classlist_final = pd.merge(classlist_ab, classlist_cd, 
                           how='outer', on='Student number')

# %%
classlist_final
# Out:
#      Student number  Surname_x Initials_x  Final mark_x Class_x  \
# 0          15476227     AFONSO          L         47.72       E
# 1          15311279   ALBERTYN      F J H         57.52       A
# 2          15637913  ALEXANDER          L         90.68       E
# 3          15124150        BAM        A J         56.43       E
# 4          15829626     BARROW        S B         79.64       E
# ..              ...        ...        ...           ...     ...
# 655        16987101        NaN        NaN           NaN     NaN
# 656        16443144        NaN        NaN           NaN     NaN
# 657        17140293        NaN        NaN           NaN     NaN
# 658        16771354        NaN        NaN           NaN     NaN
# 659        17094607        NaN        NaN           NaN     NaN
#
#                           Surname_y  Initials_y  Final mark_y Class_y
# 0                               NaN         NaN           NaN     NaN
# ...

# %% [markdown]
# 3.1.4 Applying concat() and merge()

# %%
# Import pandas.
import pandas as pd

# Read CSV file from the current working directory.
transactions_2010 = pd.read_csv('transactions_2010.csv')

# View the DataFrame.
print(transactions_2010.shape)
transactions_2010.head()
# Out:
# (26850, 6)
#   InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID
# 0    536365    85123A         6  2010-12-01 8:26       2.55       17850
# 1    536365     71053         6  2010-12-01 8:26       3.39       17850
# 2    536365    84406B         8  2010-12-01 8:26       2.75       17850
# 3    536365    84029G         6  2010-12-01 8:26       3.39       17850
# 4    536365    84029E         6  2010-12-01 8:26       3.39       17850

# %%
len(transactions_2010)
# Out:
# 26850

# %%
# How many rows?
print(f"{transactions_2010.shape[0]} rows for transactions_2010")
# Out:
# 26850 rows for transactions_2010

# %%
print(f"{transactions_2010.shape[1]} rows for transactions_2010")
# Out:
# 6 rows for transactions_2010

# %%
# Read CSV file from the current working directory.
transactions_2011 = pd.read_csv('transactions_2011.csv')

# View the DataFrame.
print(transactions_2011.shape)
transactions_2011.head()
# Out:
# (379979, 6)
#   InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID
# 0    539993     22386        10  2011-01-04 10:00       1.95       13313
# 1    539993     21499        25  2011-01-04 10:00       0.42       13313
# 2    539993     21498        25  2011-01-04 10:00       0.42       13313
# 3    539993     22379         5  2011-01-04 10:00       2.10       13313
# 4    539993     20718        10  2011-01-04 10:00       1.25       13313

# %%
# concatenate both tables
total_transactions = pd.concat([transactions_2010, transactions_2011])
total_transactions.shape
# Out:
# (406829, 6)

# %%
# Combine the two DataFrames with the concat() function
# The two DataFrames are transactions_2010 and transactions_2011.
transactions = pd.concat([transactions_2010, transactions_2011], axis=0)

# %%
transactions
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 379974    581587     22613        12  2011-12-09 12:50       0.85       12680
# 379975    581587     22899         6  2011-12-09 12:50       2.10       12680
# 379976    581587     23254         4  2011-12-09 12:50       4.15       12680
# 379977    581587     23255         4  2011-12-09 12:50       4.15       12680
# 379978    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# [406829 rows x 6 columns]

# %%
# Read CSV file from the current working directory.
products = pd.read_csv('products.csv')

# %%
products
# Out:
#          StockCode                        Description
# 0            10002         INFLATABLE POLITICAL GLOBE
# 1            10080           GROOVY CACTUS INFLATABLE
# 2            10120                       DOGGY RUBBER
# 3           10123C               HEARTS WRAPPING TAPE
# 4           10124A        SPOTS ON RED BOOKCOVER TAPE
# ...            ...                                ...
# 3940  gift_0001_20  Dotcomgiftshop Gift Voucher £20.0
# 3941  gift_0001_30  Dotcomgiftshop Gift Voucher £30.0
# 3942  gift_0001_40  Dotcomgiftshop Gift Voucher £40.0
# 3943  gift_0001_50  Dotcomgiftshop Gift Voucher £50.0
# 3944             m                             Manual
#
# [3945 rows x 2 columns]

# %%
transactions_description = pd.merge(transactions, products, how='left', on='StockCode')

# %%
transactions_description
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 406824    581587     22613        12  2011-12-09 12:50       0.85       12680
# 406825    581587     22899         6  2011-12-09 12:50       2.10       12680
# 406826    581587     23254         4  2011-12-09 12:50       4.15       12680
# 406827    581587     23255         4  2011-12-09 12:50       4.15       12680
# 406828    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# ...

# %%
# View the new DataFrame
transactions_description.head()
# Out:
#   InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  2010-12-01 8:26       2.55       17850
# 1    536365     71053         6  2010-12-01 8:26       3.39       17850
# 2    536365    84406B         8  2010-12-01 8:26       2.75       17850
# 3    536365    84029G         6  2010-12-01 8:26       3.39       17850
# 4    536365    84029E         6  2010-12-01 8:26       3.39       17850
#
#                            Description
# 0   CREAM HANGING HEART T-LIGHT HOLDER
# 1                  WHITE METAL LANTERN
# 2       CREAM CUPID HEARTS COAT HANGER
# 3  KNITTED UNION FLAG HOT WATER BOTTLE
# 4       RED WOOLLY HOTTIE WHITE HEART.

# %%
transactions_description.tail()
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 406824    581587     22613        12  2011-12-09 12:50       0.85       12680
# 406825    581587     22899         6  2011-12-09 12:50       2.10       12680
# 406826    581587     23254         4  2011-12-09 12:50       4.15       12680
# 406827    581587     23255         4  2011-12-09 12:50       4.15       12680
# 406828    581587     22138         3  2011-12-09 12:50       4.95       12680
#
#                             Description
# 406824      PACK OF 20 SPACEBOY NAPKINS
# 406825      CHILDREN'S APRON DOLLY GIRL
# 406826     CHILDRENS CUTLERY DOLLY GIRL
# 406827  CHILDRENS CUTLERY CIRCUS PARADE
# 406828     BAKING SET 9 PIECE RETROSPOT

# %%
# Read CSV file from the current working directory.
customers = pd.read_csv('customers.csv')

# %%
customers
# Out:
#       CustomerID         Country
# 0          12346  United Kingdom
# 1          12347         Iceland
# 2          12348         Finland
# 3          12349           Italy
# 4          12350          Norway
# ...          ...             ...
# 4375       18280  United Kingdom
# 4376       18281  United Kingdom
# 4377       18282  United Kingdom
# 4378       18283  United Kingdom
# 4379       18287  United Kingdom
#
# [4380 rows x 2 columns]

# %%
transactions_description_customers = pd.merge(transactions_description, customers, how='left', on='CustomerID')

# %%
transactions_description_customers
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 407750    581587     22613        12  2011-12-09 12:50       0.85       12680
# 407751    581587     22899         6  2011-12-09 12:50       2.10       12680
# 407752    581587     23254         4  2011-12-09 12:50       4.15       12680
# 407753    581587     23255         4  2011-12-09 12:50       4.15       12680
# 407754    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# ...

# %%
# Use the append() function to combine two DataFrames.
results_1 = transactions_2010.append(transactions_2011)

# View the output.
results_1
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 379974    581587     22613        12  2011-12-09 12:50       0.85       12680
# 379975    581587     22899         6  2011-12-09 12:50       2.10       12680
# 379976    581587     23254         4  2011-12-09 12:50       4.15       12680
# 379977    581587     23255         4  2011-12-09 12:50       4.15       12680
# 379978    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# [406829 rows x 6 columns]

# %%
# Import Pandas.
import pandas as pd

# Import the CSV files.
classlist_a = pd.read_csv('classlist_a.csv')
classlist_b = pd.read_csv('classlist_b.csv')
classlist_c = pd.read_csv('classlist_c.csv')
classlist_d = pd.read_csv('classlist_d.csv')

# %%
classlist_a
# Out:
#      Student number    Surname Initials  Final mark Class
# 0          15476227     AFONSO        L       47.72     E
# 1          15311279   ALBERTYN    F J H       57.52     A
# 2          15637913  ALEXANDER        L       90.68     E
# 3          15124150        BAM      A J       56.43     E
# 4          15829626     BARROW      S B       79.64     E
# ..              ...        ...      ...         ...   ...
# 140        15198162    WEGENER      A M       48.83     E
# 141        15618935  WEIGHTMAN      C J       88.33     A
# 142        15715396   WILLIAMS        N       75.66     E
# 143        15849390      YOUNG      V A       88.05     E
# 144        15897184    ZONDAGH        L       59.10     E
#
# [145 rows x 5 columns]

# %%
#concat 4 DataFrames with concat()

# %%
classlist_final = pd.concat([classlist_a, classlist_b, classlist_c, classlist_d])

# %%
classlist_final
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class
# 0       E
# 1       A
# 2       E
# ...

# %%
classlist_final.shape
# Out:
# (675, 5)

# %% [markdown]
# SPLIT - APPLY - COMBINE PRACTICE

# %%
# create group 1
group_surname = classlist_final.groupby('Surname')

# %%
print(group_surname)

# %%
# create group 2
group_marks = classlist_final.groupby('Final mark')

# %%
print(group_marks)

# %%
# Create group 3.
group_surname_marks = classlist_final.groupby(['Surname', 'Final mark'])

# View the DataFrame.
group_surname_marks

# %%
print(group_surname_marks)

# %%
# Create splitting within groups.
group_surname_marks.sum()
# Out:
#                                            Student number
# Surname                        Final mark
# ABRAHAMS                       48.00             15793648
# ACKERMANN                      45.00             17483638
# ADENDORFF                      76.50             15849376
# AFONSO                         47.72             15476227
# ALBERTUS                       57.00             16564499
# ...                                                   ...
# YOUNG                          88.05             15849390
# ZINN                           74.00             17094607
# ZONDAGH                        59.10             15897184
# ZONDI                          74.46             16324773
# ZUMA                           64.50             16782879
#
# [673 rows x 1 columns]

# %%
# Use the size() function.
group_surname_marks.size()
# Out:
# Surname                         Final mark
# ABRAHAMS                        48.00         1
# ACKERMANN                       45.00         1
# ADENDORFF                       76.50         1
# AFONSO                          47.72         1
# ALBERTUS                        57.00         1
#                                              ..
# YOUNG                           88.05         1
# ZINN                            74.00         1
# ZONDAGH                         59.10         1
# ZONDI                           74.46         1
# ZUMA                            64.50         1
# Length: 673, dtype: int64

# %%
import pandas as pd

# %%
# Use the size() function.
group_surname_marks.size()
# Out:
# Surname                         Final mark
# ABRAHAMS                        48.00         1
# ACKERMANN                       45.00         1
# ADENDORFF                       76.50         1
# AFONSO                          47.72         1
# ALBERTUS                        57.00         1
#                                              ..
# YOUNG                           88.05         1
# ZINN                            74.00         1
# ZONDAGH                         59.10         1
# ZONDI                           74.46         1
# ZUMA                            64.50         1
# Length: 673, dtype: int64

# %%
# The size() based on surname column.
group_surname.size()
# Out:
# Surname
# ABRAHAMS                          1
# ACKERMANN                         1
# ADENDORFF                         1
# AFONSO                            1
# ALBERTUS                          1
#                                  ..
# YOUNG                             1
# ZINN                              1
# ZONDAGH                           1
# ZONDI                             1
# ZUMA                              1
# Length: 534, dtype: int64

# %%
# Create group 4.
group_surname_initials = classlist_final.groupby(['Surname', 'Initials'])

# %%
group_surname_initials

# %%
group_surname_initials.size()
# Out:
# Surname                         Initials
# ABRAHAMS                        B             1
# ACKERMANN                       E             1
# ADENDORFF                       K             1
# AFONSO                          L             1
# ALBERTUS                        S             1
#                                              ..
# YOUNG                           V A           1
# ZINN                            A             1
# ZONDAGH                         L             1
# ZONDI                           WP            1
# ZUMA                            MC            1
# Length: 666, dtype: int64

# %%
# Use the count() function.
group_surname_initials.count()
# Out:
#                                            Student number  Final mark  Class
# Surname                        Initials
# ABRAHAMS                       B                        1           1      1
# ACKERMANN                      E                        1           1      1
# ADENDORFF                      K                        1           1      1
# AFONSO                         L                        1           1      1
# ALBERTUS                       S                        1           1      1
# ...                                                   ...         ...    ...
# YOUNG                          V A                      1           1      1
# ZINN                           A                        1           1      1
# ZONDAGH                        L                        1           1      1
# ZONDI                          WP                       1           1      1
# ZUMA                           MC                       1           1      1
#
# ...

# %%
# Create group 4.
group_surname_initials_marks = classlist_final.groupby(['Surname', 'Initials','Final mark'])

# %%
group_surname_initials_marks

# %%
group_surname_initials_marks.size()
# Out:
# Surname                         Initials    Final mark
# ABRAHAMS                        B           48.00         1
# ACKERMANN                       E           45.00         1
# ADENDORFF                       K           76.50         1
# AFONSO                          L           47.72         1
# ALBERTUS                        S           57.00         1
#                                                          ..
# YOUNG                           V A         88.05         1
# ZINN                            A           74.00         1
# ZONDAGH                         L           59.10         1
# ZONDI                           WP          74.46         1
# ZUMA                            MC          64.50         1
# Length: 675, dtype: int64

# %%
group_surname_initials_marks.count()
# Out:
#                                                       Student number  Class
# Surname                        Initials   Final mark
# ABRAHAMS                       B          48.00                    1      1
# ACKERMANN                      E          45.00                    1      1
# ADENDORFF                      K          76.50                    1      1
# AFONSO                         L          47.72                    1      1
# ALBERTUS                       S          57.00                    1      1
# ...                                                              ...    ...
# YOUNG                          V A        88.05                    1      1
# ZINN                           A          74.00                    1      1
# ZONDAGH                        L          59.10                    1      1
# ZONDI                          WP         74.46                    1      1
# ZUMA                           MC         64.50                    1      1
#
# ...

# %%
# Create group 5.
group_surname_marks = classlist_final.groupby(['Surname', 'Final mark'])

# %%
group_surname_marks.count()
# Out:
#                                            Student number  Initials  Class
# Surname                        Final mark
# ABRAHAMS                       48.00                    1         1      1
# ACKERMANN                      45.00                    1         1      1
# ADENDORFF                      76.50                    1         1      1
# AFONSO                         47.72                    1         1      1
# ALBERTUS                       57.00                    1         1      1
# ...                                                   ...       ...    ...
# YOUNG                          88.05                    1         1      1
# ZINN                           74.00                    1         1      1
# ZONDAGH                        59.10                    1         1      1
# ZONDI                          74.46                    1         1      1
# ZUMA                           64.50                    1         1      1
#
# [673 rows x 3 columns]

# %%
group_surname_marks.size()
# Out:
# Surname                         Final mark
# ABRAHAMS                        48.00         1
# ACKERMANN                       45.00         1
# ADENDORFF                       76.50         1
# AFONSO                          47.72         1
# ALBERTUS                        57.00         1
#                                              ..
# YOUNG                           88.05         1
# ZINN                            74.00         1
# ZONDAGH                         59.10         1
# ZONDI                           74.46         1
# ZUMA                            64.50         1
# Length: 673, dtype: int64

# %% [markdown]
# 3.1.8 Applying groupby() and aggregate() methods

# %%
# Read CSV file from the current working directory.
transactions_2010 = pd.read_csv('transactions_2010.csv')

# %%
# Read CSV file from the current working directory.
transactions_2011 = pd.read_csv('transactions_2011.csv')

# %%
# Read CSV file from the current working directory.
customers = pd.read_csv('customers.csv')

# %%
# Read CSV file from the current working directory.
products = pd.read_csv('products.csv')

# %%
# concat transactions

total_transactions = pd.concat([transactions_2010, transactions_2011], axis = 0)

# %%
total_transactions
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 379974    581587     22613        12  2011-12-09 12:50       0.85       12680
# 379975    581587     22899         6  2011-12-09 12:50       2.10       12680
# 379976    581587     23254         4  2011-12-09 12:50       4.15       12680
# 379977    581587     23255         4  2011-12-09 12:50       4.15       12680
# 379978    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# [406829 rows x 6 columns]

# %%
# concat transactions

total_transactions2 = pd.concat([transactions_2010, transactions_2011], axis = 1)

# %%
total_transactions2
# Out:
#        InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A       6.0  2010-12-01 8:26       2.55     17850.0
# 1         536365     71053       6.0  2010-12-01 8:26       3.39     17850.0
# 2         536365    84406B       8.0  2010-12-01 8:26       2.75     17850.0
# 3         536365    84029G       6.0  2010-12-01 8:26       3.39     17850.0
# 4         536365    84029E       6.0  2010-12-01 8:26       3.39     17850.0
# ...          ...       ...       ...              ...        ...         ...
# 379974       NaN       NaN       NaN              NaN        NaN         NaN
# 379975       NaN       NaN       NaN              NaN        NaN         NaN
# 379976       NaN       NaN       NaN              NaN        NaN         NaN
# 379977       NaN       NaN       NaN              NaN        NaN         NaN
# 379978       NaN       NaN       NaN              NaN        NaN         NaN
#
# ...

# %%
# concat transactions

total_transactions = pd.concat([transactions_2010, transactions_2011], axis = 0)

# %%
total_transactions
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 379974    581587     22613        12  2011-12-09 12:50       0.85       12680
# 379975    581587     22899         6  2011-12-09 12:50       2.10       12680
# 379976    581587     23254         4  2011-12-09 12:50       4.15       12680
# 379977    581587     23255         4  2011-12-09 12:50       4.15       12680
# 379978    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# [406829 rows x 6 columns]

# %%
transactions_description = pd.merge(total_transactions, products, how = 'left', on = 'StockCode')

# %%
transactions_description
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 406824    581587     22613        12  2011-12-09 12:50       0.85       12680
# 406825    581587     22899         6  2011-12-09 12:50       2.10       12680
# 406826    581587     23254         4  2011-12-09 12:50       4.15       12680
# 406827    581587     23255         4  2011-12-09 12:50       4.15       12680
# 406828    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# ...

# %%
transactions_description_country = pd.merge(transactions_description, customers, how = 'left', on = 'CustomerID')

# %%
transactions_description_country
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1         536365     71053         6   2010-12-01 8:26       3.39       17850
# 2         536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3         536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4         536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...          ...       ...       ...               ...        ...         ...
# 407750    581587     22613        12  2011-12-09 12:50       0.85       12680
# 407751    581587     22899         6  2011-12-09 12:50       2.10       12680
# 407752    581587     23254         4  2011-12-09 12:50       4.15       12680
# 407753    581587     23255         4  2011-12-09 12:50       4.15       12680
# 407754    581587     22138         3  2011-12-09 12:50       4.95       12680
#
# ...

# %%
transactions_description_country.shape
# Out:
# (407755, 8)

# %%
transactions_description_country.head()
# Out:
#   InvoiceNo StockCode  Quantity      InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  2010-12-01 8:26       2.55       17850
# 1    536365     71053         6  2010-12-01 8:26       3.39       17850
# 2    536365    84406B         8  2010-12-01 8:26       2.75       17850
# 3    536365    84029G         6  2010-12-01 8:26       3.39       17850
# 4    536365    84029E         6  2010-12-01 8:26       3.39       17850
#
#                            Description         Country
# 0   CREAM HANGING HEART T-LIGHT HOLDER  United Kingdom
# 1                  WHITE METAL LANTERN  United Kingdom
# 2       CREAM CUPID HEARTS COAT HANGER  United Kingdom
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  United Kingdom
# 4       RED WOOLLY HOTTIE WHITE HEART.  United Kingdom

# %%
# Question 1: What are the total sales per country?

# Transaction totals: include a column of total sales as "Sales Total"
transactions_description_country["SaleTotal"] = (transactions_description_country["Quantity"] * 
                                                 transactions_description_country["UnitPrice"])

# %%
transactions_description_country["SaleTotal"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 407750    10.20
# 407751    12.60
# 407752    16.60
# 407753    16.60
# 407754    14.85
# Name: SaleTotal, Length: 407755, dtype: float64

# %%
# Total sales by country.
transactions_description_country.groupby("Country")[["SaleTotal"]].sum()
# Out:
#                         SaleTotal
# Country
# Australia              138467.410
# Austria                 16735.230
# Bahrain                   548.400
# Belgium                 47682.270
# Brazil                   1143.600
# Canada                   3666.380
# Channel Islands         20086.290
# Cyprus                  15712.880
# Czech Republic            707.720
# Denmark                 19587.200
# EIRE                   250285.220
# European Community       1291.750
# Finland                 22326.740
# France                 196712.840
# Germany                221698.210
# Greece                   4710.520
# Iceland                  4310.000
# Israel                   6994.250
# Italy                   16890.510
# Japan                   35340.620
# Lebanon                  1693.880
# Lithuania                1661.060
# Malta                    2505.470
# Netherlands            284661.540
# Norway                  35163.460
# Poland                   7213.140
# ...

# %%
# Total sales by country in ascending order
transactions_description_country.groupby("Country")[["SaleTotal"]].sum \
().sort_values("SaleTotal", ascending=False)
# Out:
#                         SaleTotal
# Country
# United Kingdom        6767873.394
# Netherlands            284661.540
# EIRE                   250285.220
# Germany                221698.210
# France                 196712.840
# Australia              138467.410
# Spain                   59615.980
# Switzerland             56321.950
# Belgium                 47682.270
# Sweden                  36595.910
# Japan                   35340.620
# Norway                  35163.460
# Portugal                29059.810
# Finland                 22326.740
# Channel Islands         20086.290
# Denmark                 19587.200
# Italy                   16890.510
# Austria                 16735.230
# Cyprus                  15712.880
# Singapore                9120.390
# Poland                   7213.140
# Israel                   6994.250
# Greece                   4710.520
# Iceland                  4310.000
# Canada                   3666.380
# Unspecified              2667.070
# ...

# %%
# Average sales by country in ascending order
# Total and mean sales by country.
transactions_description_country.groupby("Country")[["SaleTotal"]] \
.agg(["sum", "mean"])
# Out:
#                         SaleTotal
#                               sum        mean
# Country
# Australia              138467.410  104.032615
# Austria                 16735.230   26.313255
# Bahrain                   548.400   32.258824
# Belgium                 47682.270   20.876651
# Brazil                   1143.600   35.737500
# Canada                   3666.380   24.280662
# Channel Islands         20086.290   26.499063
# Cyprus                  15712.880   21.147887
# Czech Republic            707.720   23.590667
# Denmark                 19587.200   45.445940
# EIRE                   250285.220   33.438239
# European Community       1291.750   21.176230
# Finland                 22326.740   32.124806
# France                 196712.840   23.167217
# Germany                221698.210   23.348943
# Greece                   4710.520   32.263836
# Iceland                  4310.000   23.681319
# Israel                   6994.250   27.977000
# ...

# %%
# Average sales by country in ascending order
# Total and mean sales by country.

# Total sales by country in ascending order
transactions_description_country.groupby("Country")[["SaleTotal"]].agg(["sum", "mean"]).sort_values \
([("SaleTotal", "mean")], ascending = False)
# Out:
#                         SaleTotal
#                               sum        mean
# Country
# Netherlands            284661.540  120.059696
# Australia              138467.410  104.032615
# Japan                   35340.620   98.716816
# Sweden                  36595.910   79.211926
# Lithuania                1661.060   47.458857
# Denmark                 19587.200   45.445940
# Singapore                9120.390   39.827031
# Lebanon                  1693.880   37.641778
# Brazil                   1143.600   35.737500
# EIRE                   250285.220   33.438239
# Norway                  35163.460   32.378877
# Greece                   4710.520   32.263836
# Bahrain                   548.400   32.258824
# Finland                 22326.740   32.124806
# Switzerland             56321.950   29.627538
# Israel                   6994.250   27.977000
# United Arab Emirates     1902.280   27.974706
# Channel Islands         20086.290   26.499063
# ...

# %%
# Sort total and average sales by country.
transactions_description_country.groupby("Country")[["SaleTotal"]] \
.agg(["sum", "mean"]) \
.sort_values([("SaleTotal", "sum")], ascending=False)
# Out:
#                         SaleTotal
#                               sum        mean
# Country
# United Kingdom        6767873.394   18.702086
# Netherlands            284661.540  120.059696
# EIRE                   250285.220   33.438239
# Germany                221698.210   23.348943
# France                 196712.840   23.167217
# Australia              138467.410  104.032615
# Spain                   59615.980   21.678538
# Switzerland             56321.950   29.627538
# Belgium                 47682.270   20.876651
# Sweden                  36595.910   79.211926
# Japan                   35340.620   98.716816
# Norway                  35163.460   32.378877
# Portugal                29059.810   19.635007
# Finland                 22326.740   32.124806
# Channel Islands         20086.290   26.499063
# Denmark                 19587.200   45.445940
# Italy                   16890.510   21.034259
# Austria                 16735.230   26.313255
# ...

# %%
# Sort total and average sales by country.
transactions_description_country.groupby("Country")[["SaleTotal"]] \
.agg(["sum", "mean"]) \
.sort_values([("SaleTotal", "mean")], ascending=False)
# Out:
#                         SaleTotal
#                               sum        mean
# Country
# Netherlands            284661.540  120.059696
# Australia              138467.410  104.032615
# Japan                   35340.620   98.716816
# Sweden                  36595.910   79.211926
# Lithuania                1661.060   47.458857
# Denmark                 19587.200   45.445940
# Singapore                9120.390   39.827031
# Lebanon                  1693.880   37.641778
# Brazil                   1143.600   35.737500
# EIRE                   250285.220   33.438239
# Norway                  35163.460   32.378877
# Greece                   4710.520   32.263836
# Bahrain                   548.400   32.258824
# Finland                 22326.740   32.124806
# Switzerland             56321.950   29.627538
# Israel                   6994.250   27.977000
# United Arab Emirates     1902.280   27.974706
# Channel Islands         20086.290   26.499063
# ...

# %%
# Top selling product.
transactions_description_country.groupby("Description")[["SaleTotal"]] \
.agg(["sum", "mean"]) \
.sort_values([("SaleTotal", "sum")], ascending=False)
# Out:
#                                     SaleTotal
#                                           sum        mean
# Description
# REGENCY CAKESTAND 3 TIER            133112.65   69.656018
# CREAM HANGING HEART T-LIGHT HOLDER   94312.50   45.342548
# JUMBO BAG RED RETROSPOT              83277.06   50.046310
# POSTAGE                              68479.24   56.038658
# PARTY BUNTING                        67791.18   47.773911
# ...                                       ...         ...
# WHITE CHERRY LIGHTS                    -54.00  -54.000000
# CHALKBOARD KITCHEN ORGANISER           -87.80  -17.560000
# Discount                             -5696.22  -73.976883
# CRUK Commission                      -7933.43 -495.839375
# Manual                              -58385.46 -125.560129
#
# [3659 rows x 2 columns]

# %%
# Import Pandas.
import pandas as pd

# Read the CSV files from the current working directory.
transactions = pd.read_csv("transactions_2010.csv")
products = pd.read_csv("products.csv")

# %%
# View the DataFrames.
transactions.shape
# Out:
# (26850, 6)

# %%
transactions
# Out:
#       InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID
# 0        536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1        536365     71053         6   2010-12-01 8:26       3.39       17850
# 2        536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3        536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4        536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...         ...       ...       ...               ...        ...         ...
# 26845    539988     84380         1  2010-12-23 16:06       1.25       18116
# 26846    539988    84849D         1  2010-12-23 16:06       1.69       18116
# 26847    539988    84849B         1  2010-12-23 16:06       1.69       18116
# 26848    539988     22854         2  2010-12-23 16:06       4.95       18116
# 26849    539988    47559B         2  2010-12-23 16:06       1.25       18116
#
# [26850 rows x 6 columns]

# %%
products
# Out:
#          StockCode                        Description
# 0            10002         INFLATABLE POLITICAL GLOBE
# 1            10080           GROOVY CACTUS INFLATABLE
# 2            10120                       DOGGY RUBBER
# 3           10123C               HEARTS WRAPPING TAPE
# 4           10124A        SPOTS ON RED BOOKCOVER TAPE
# ...            ...                                ...
# 3940  gift_0001_20  Dotcomgiftshop Gift Voucher £20.0
# 3941  gift_0001_30  Dotcomgiftshop Gift Voucher £30.0
# 3942  gift_0001_40  Dotcomgiftshop Gift Voucher £40.0
# 3943  gift_0001_50  Dotcomgiftshop Gift Voucher £50.0
# 3944             m                             Manual
#
# [3945 rows x 2 columns]

# %%
trans_prod = pd.merge(transactions, products, how = 'left', on = 'StockCode')

# %%
trans_prod
# Out:
#       InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0        536365    85123A         6   2010-12-01 8:26       2.55       17850
# 1        536365     71053         6   2010-12-01 8:26       3.39       17850
# 2        536365    84406B         8   2010-12-01 8:26       2.75       17850
# 3        536365    84029G         6   2010-12-01 8:26       3.39       17850
# 4        536365    84029E         6   2010-12-01 8:26       3.39       17850
# ...         ...       ...       ...               ...        ...         ...
# 26845    539988     84380         1  2010-12-23 16:06       1.25       18116
# 26846    539988    84849D         1  2010-12-23 16:06       1.69       18116
# 26847    539988    84849B         1  2010-12-23 16:06       1.69       18116
# 26848    539988     22854         2  2010-12-23 16:06       4.95       18116
# 26849    539988    47559B         2  2010-12-23 16:06       1.25       18116
#
#                                Description
# ...

# %%
transactions_stack = transactions.stack()

# %%
transactions_stack
# Out:
# 0      InvoiceNo                536365
#        StockCode                85123A
#        Quantity                      6
#        InvoiceDate     2010-12-01 8:26
#        UnitPrice                  2.55
#                             ...
# 26849  StockCode                47559B
#        Quantity                      2
#        InvoiceDate    2010-12-23 16:06
#        UnitPrice                  1.25
#        CustomerID                18116
# Length: 161100, dtype: object

# %%
print(transactions_stack)
# Out:
# 0      InvoiceNo                536365
#        StockCode                85123A
#        Quantity                      6
#        InvoiceDate     2010-12-01 8:26
#        UnitPrice                  2.55
#                             ...
# 26849  StockCode                47559B
#        Quantity                      2
#        InvoiceDate    2010-12-23 16:06
#        UnitPrice                  1.25
#        CustomerID                18116
# Length: 161100, dtype: object

# %%
# View the data type(s).
print(type(transactions_stack))

# View the specified index.
print(transactions_stack.index)
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex([(    0,   'InvoiceNo'),
#             (    0,   'StockCode'),
#             (    0,    'Quantity'),
#             (    0, 'InvoiceDate'),
#             (    0,   'UnitPrice'),
#             (    0,  'CustomerID'),
#             (    1,   'InvoiceNo'),
#             (    1,   'StockCode'),
#             (    1,    'Quantity'),
#             (    1, 'InvoiceDate'),
#             ...
#             (26848,    'Quantity'),
#             (26848, 'InvoiceDate'),
#             (26848,   'UnitPrice'),
#             (26848,  'CustomerID'),
#             (26849,   'InvoiceNo'),
#             (26849,   'StockCode'),
#             (26849,    'Quantity'),
#             (26849, 'InvoiceDate'),
#             (26849,   'UnitPrice'),
#             (26849,  'CustomerID')],
#            length=161100)

# %%
transactions_unstack = transactions_stack.unstack()

# %%
transactions_unstack
# Out:
#       InvoiceNo StockCode Quantity       InvoiceDate UnitPrice CustomerID
# 0        536365    85123A        6   2010-12-01 8:26      2.55      17850
# 1        536365     71053        6   2010-12-01 8:26      3.39      17850
# 2        536365    84406B        8   2010-12-01 8:26      2.75      17850
# 3        536365    84029G        6   2010-12-01 8:26      3.39      17850
# 4        536365    84029E        6   2010-12-01 8:26      3.39      17850
# ...         ...       ...      ...               ...       ...        ...
# 26845    539988     84380        1  2010-12-23 16:06      1.25      18116
# 26846    539988    84849D        1  2010-12-23 16:06      1.69      18116
# 26847    539988    84849B        1  2010-12-23 16:06      1.69      18116
# 26848    539988     22854        2  2010-12-23 16:06      4.95      18116
# 26849    539988    47559B        2  2010-12-23 16:06      1.25      18116
#
# [26850 rows x 6 columns]

# %%
# Melt the products DataFrame.
trans_prod.melt(id_vars='StockCode', value_vars='Description')
# Out:
#       StockCode     variable                                value
# 0        85123A  Description   CREAM HANGING HEART T-LIGHT HOLDER
# 1         71053  Description                  WHITE METAL LANTERN
# 2        84406B  Description       CREAM CUPID HEARTS COAT HANGER
# 3        84029G  Description  KNITTED UNION FLAG HOT WATER BOTTLE
# 4        84029E  Description       RED WOOLLY HOTTIE WHITE HEART.
# ...         ...          ...                                  ...
# 26845     84380  Description    SET OF 3 BUTTERFLY COOKIE CUTTERS
# 26846    84849D  Description                HOT BATHS SOAP HOLDER
# 26847    84849B  Description               FAIRY SOAP SOAP HOLDER
# 26848     22854  Description          CREAM SWEETHEART EGG HOLDER
# 26849    47559B  Description                  TEA TIME OVEN GLOVE
#
# [26850 rows x 3 columns]

# %%
products
# Out:
#          StockCode                        Description
# 0            10002         INFLATABLE POLITICAL GLOBE
# 1            10080           GROOVY CACTUS INFLATABLE
# 2            10120                       DOGGY RUBBER
# 3           10123C               HEARTS WRAPPING TAPE
# 4           10124A        SPOTS ON RED BOOKCOVER TAPE
# ...            ...                                ...
# 3940  gift_0001_20  Dotcomgiftshop Gift Voucher £20.0
# 3941  gift_0001_30  Dotcomgiftshop Gift Voucher £30.0
# 3942  gift_0001_40  Dotcomgiftshop Gift Voucher £40.0
# 3943  gift_0001_50  Dotcomgiftshop Gift Voucher £50.0
# 3944             m                             Manual
#
# [3945 rows x 2 columns]

# %%
# Melt the products DataFrame.
trans_prod.melt(id_vars= ['StockCode', 'Description'])
# Out:
#        StockCode                          Description    variable   value
# 0         85123A   CREAM HANGING HEART T-LIGHT HOLDER   InvoiceNo  536365
# 1          71053                  WHITE METAL LANTERN   InvoiceNo  536365
# 2         84406B       CREAM CUPID HEARTS COAT HANGER   InvoiceNo  536365
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE   InvoiceNo  536365
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.   InvoiceNo  536365
# ...          ...                                  ...         ...     ...
# 134245     84380    SET OF 3 BUTTERFLY COOKIE CUTTERS  CustomerID   18116
# 134246    84849D                HOT BATHS SOAP HOLDER  CustomerID   18116
# 134247    84849B               FAIRY SOAP SOAP HOLDER  CustomerID   18116
# 134248     22854          CREAM SWEETHEART EGG HOLDER  CustomerID   18116
# 134249    47559B                  TEA TIME OVEN GLOVE  CustomerID   18116
#
# [134250 rows x 4 columns]

# %%
#PIVOT dataframes

import pandas as pd

# %%
astronauts = pd.read_csv('astronauts.csv')

# %%
astronauts
# Out:
#                       Name    Year  Group   Status  Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active   5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired  03/07/1936
# 2         James C. Adamson  1984.0   10.0  Retired  03/03/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired   5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired   1/20/1930
# ..                     ...     ...    ...      ...         ...
# 352          David A. Wolf  1990.0   13.0  Retired   8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired   7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired  02/07/1932
# 355          John W. Young  1962.0    2.0  Retired   9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired   6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ...

# %%
# What is the status and number of space flights undertaken by each astronaut?

astronauts.pivot(index="Name", columns="Status", values="Space Flights")
# Out:
# Status                    Active  Deceased  Management  Retired
# Name
# Alan B. Shepard Jr.          NaN       2.0         NaN      NaN
# Alan G. Poindexter           NaN       2.0         NaN      NaN
# Alan L. Bean                 NaN       NaN         NaN      2.0
# Albert Sacco Jr.             NaN       NaN         NaN      1.0
# Alfred M. Worden             NaN       NaN         NaN      1.0
# ...                          ...       ...         ...      ...
# William M. Shepherd          NaN       NaN         NaN      4.0
# William R. Pogue             NaN       NaN         NaN      1.0
# William S. McArthur Jr.      NaN       NaN         4.0      NaN
# Winston E. Scott             NaN       NaN         NaN      2.0
# Yvonne D. Cagle              NaN       NaN         0.0      NaN
#
# [357 rows x 4 columns]

# %%
# What is the status, number of spacewalks and spaceflights for each astronaut?

astronauts.pivot(index="Name", columns="Status", values=["Space Walks","Space Flights"])
# Out:
#                          Space Walks                              \
# Status                        Active Deceased Management Retired
# Name
# Alan B. Shepard Jr.              NaN      2.0        NaN     NaN
# Alan G. Poindexter               NaN      0.0        NaN     NaN
# Alan L. Bean                     NaN      NaN        NaN     3.0
# Albert Sacco Jr.                 NaN      NaN        NaN     0.0
# Alfred M. Worden                 NaN      NaN        NaN     1.0
# ...                              ...      ...        ...     ...
# William M. Shepherd              NaN      NaN        NaN     0.0
# William R. Pogue                 NaN      NaN        NaN     2.0
# William S. McArthur Jr.          NaN      NaN        4.0     NaN
# Winston E. Scott                 NaN      NaN        NaN     3.0
# Yvonne D. Cagle                  NaN      NaN        0.0     NaN
#
#                          Space Flights
# Status                          Active Deceased Management Retired
# Name
# ...

# %%
# Import pandas.
import pandas as pd

# Read the CSV files from the current working directory
classlist_a = pd.read_csv('classlist_a.csv')
classlist_b = pd.read_csv('classlist_b.csv')
classlist_c = pd.read_csv('classlist_c.csv')
classlist_d = pd.read_csv('classlist_d.csv')

# %%
classlist = pd.concat([classlist_a, classlist_b, classlist_c, classlist_d])

# %%
classlist
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class
# 0       E
# 1       A
# 2       E
# ...

# %%
# She wants the Class column to be changed from a string to an integer. 
# For example, the A and E should be replaced with 1 and 0. 

# Use the map() function only on a Pandas Series.
classlist['Class_num'] = classlist.Class.map({'A':0, 'E':1})

# %%
classlist['Class_num']
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 214    1
# 215    1
# 216    0
# 217    1
# 218    1
# Name: Class_num, Length: 675, dtype: int64

# %%
classlist
# Out:
#      Student number                         Surname    Initials  Final mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class  Class_num
# 0       E          1
# ...

# %%
# The column Final mark needs to be renamed to Final_mark.

# %%
# Compare columns Class and Class_num with the loc() function.
print(classlist.loc[:, ['Class', 'Class_num']])

# Compare columns Class and Class_num with the iloc() function.
classlist.iloc[:, 4:6]
# Out:
#     Class  Class_num
# 0       E          1
# 1       A          0
# 2       E          1
# 3       E          1
# 4       E          1
# ..    ...        ...
# 214     E          1
# 215     E          1
# 216     A          0
# 217     E          1
# 218     E          1
#
# [675 rows x 2 columns]
#     Class  Class_num
# 0       E          1
# 1       A          0
# 2       E          1
# 3       E          1
# 4       E          1
# ..    ...        ...
# 214     E          1
# 215     E          1
# 216     A          0
# 217     E          1
# 218     E          1
#
# [675 rows x 2 columns]

# %%
# Rename column Final mark to Final_mark.
classlist_final = classlist.rename(columns={'Final mark':'Final_mark'})

# View the DataFrame.
classlist_final
# Out:
#      Student number                         Surname    Initials  Final_mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class  Class_num
# 0       E          1
# ...

# %%
# code snippet to return the average Final_mark for Prof Minnaar’s

# Using DataFrame.mean() method to get column average
Final_mark_average = classlist_final["Final_mark"].mean()

# %%
Final_mark_average
# Out:
# 60.134311111111096

# %% [markdown]
# 3.2.2 Introduction to apply()

# %%
# Use the apply() function applies a function to each element within a Series.
classlist_final['Surname_length'] = classlist.Surname.apply(len)

# %%
classlist_final
# Out:
#      Student number                         Surname    Initials  Final_mark  \
# 0          15476227                          AFONSO           L       47.72
# 1          15311279                        ALBERTYN       F J H       57.52
# 2          15637913                       ALEXANDER           L       90.68
# 3          15124150                             BAM         A J       56.43
# 4          15829626                          BARROW         S B       79.64
# ..              ...                             ...         ...         ...
# 214        16443144  WIJERS                          MC               93.00
# 215        14955849  WIJNBERG                        JM               47.00
# 216        17140293  WILLIAMS                        CA               43.00
# 217        16771354  WOLHUTER                        J                76.00
# 218        17094607  ZINN                            A                74.00
#
#     Class  Class_num  Surname_length
# ...

# %%
Surname_lenght_max = classlist_final["Surname_length"].max()

# %%
Surname_lenght_max
# Out:
# 30

# %%
Surname_lenght_min = classlist_final["Surname_length"].min()

# %%
Surname_lenght_min
# Out:
# 3

# %%
# Data import from GitHub

# Import a CSV data set with a URL from a website.
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
# View the DataFrame.
print(drinks.shape)
print(drinks.dtypes)
drinks.head()
# Out:
# (193, 7)
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# total_servings                    int64
# dtype: object
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent  total_servings
# 0                           0.0      Asia               0
# 1                           4.9    Europe             275
# 2                           0.7    Africa              39
# ...

# %%
# Include a column for total wine servings

cols = ['beer_servings', 'spirit_servings', 'wine_servings']

drinks['total_servings'] = drinks[cols].sum(axis=1)

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent  total_servings
# 0                             0.0           Asia               0
# 1                             4.9         Europe             275
# ...

# %%
drinks.sort_values(by=['total_servings'], inplace=True, ascending=False)

# %%
drinks
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# ..                  ...            ...              ...            ...
# 90               Kuwait              0                0              0
# 147          San Marino              0                0              0
# 79                 Iran              0                0              0
# 158             Somalia              0                0              0
# 0           Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent  total_servings
# ...

# %%
# Question 1:
# Want to apply a method to go on down direction apply max function (downward),
# max value per column
print(drinks_country.loc[:, 'beer_servings':'wine_servings'].apply(max, axis=0))
print(drinks_country.loc[:, 'beer_servings':'wine_servings'].apply(min, axis=0))
# Out:
# beer_servings      376
# spirit_servings    438
# wine_servings      370
# dtype: int64
# beer_servings      0
# spirit_servings    0
# wine_servings      0
# dtype: int64

# %%
# Average products prince and sales quantity

# Import the libraries.
import pandas as pd
import numpy as np

# Read the CSV file from the current working directory.
transactions_2010 = pd.read_csv('transactions_2010.csv')

# View DataFrame.
print(transactions_2010.shape)

# Calculate the mean quantity and price.
transactions_2010[["Quantity", "UnitPrice"]].apply(np.mean)
# Out:
# (26850, 6)
# Quantity     11.037691
# UnitPrice     3.205109
# dtype: float64

# %%
# Comparison with 2011?

# Read the CSV file from the current working directory.
transactions_2011 = pd.read_csv('transactions_2011.csv')

# View DataFrame.
print(transactions_2011.shape)

# Calculate the mean quantity and price.
transactions_2011[["Quantity", "UnitPrice"]].apply(np.mean)
# Out:
# (379979, 6)
# Quantity     12.133634
# UnitPrice     3.478515
# dtype: float64

# %% [markdown]
# 3.2.3 Introduction to applymap()

# %%
import pandas as pd
import numpy as np

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# Employ the applymap function to specified columns.
drinks_new = drinks.loc[:, 'beer_servings':'wine_servings'].applymap(float)

# %%
drinks_new
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188          333.0            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
# [193 rows x 3 columns]

# %%
# View the data types.
drinks_new.dtypes
# Out:
# beer_servings      float64
# spirit_servings    float64
# wine_servings      float64
# dtype: object

# %%
# Mr Zachariou from the All-You-Need case study, wants you to determine the total number of characters the StockCodes and 
# Descriptions columns have. 
# Do you think the applymap() function can help to answer the question?

products = pd.read_csv('products.csv')

# %%
products
# Out:
#          StockCode                        Description
# 0            10002         INFLATABLE POLITICAL GLOBE
# 1            10080           GROOVY CACTUS INFLATABLE
# 2            10120                       DOGGY RUBBER
# 3           10123C               HEARTS WRAPPING TAPE
# 4           10124A        SPOTS ON RED BOOKCOVER TAPE
# ...            ...                                ...
# 3940  gift_0001_20  Dotcomgiftshop Gift Voucher £20.0
# 3941  gift_0001_30  Dotcomgiftshop Gift Voucher £30.0
# 3942  gift_0001_40  Dotcomgiftshop Gift Voucher £40.0
# 3943  gift_0001_50  Dotcomgiftshop Gift Voucher £50.0
# 3944             m                             Manual
#
# [3945 rows x 2 columns]

# %%
# Employ the applymap function to specified columns.
products_new = products.loc[:, 'StockCode':'Description'].applymap(len)

# %%
products_new
# Out:
#       StockCode  Description
# 0             5           26
# 1             5           24
# 2             5           12
# 3             6           20
# 4             6           27
# ...         ...          ...
# 3940         12           33
# 3941         12           33
# 3942         12           33
# 3943         12           33
# 3944          1            6
#
# [3945 rows x 2 columns]

# %%
products_new.sort_values(by=['StockCode'], inplace=True, ascending=False)

# %%
products_new
# Out:
#       StockCode  Description
# 3943         12           33
# 3923         12           12
# 3942         12           33
# 3941         12           33
# 3940         12           33
# ...         ...          ...
# 3926          1            8
# 3938          1            7
# 3935          1            6
# 3922          1           15
# 3944          1            6
#
# [3945 rows x 2 columns]

# %%
products_new.sort_values(by=['Description'], inplace=True, ascending=False)

# %%
products_new
# Out:
#       StockCode  Description
# 2812          5           35
# 3520          5           35
# 3603          5           35
# 3766          5           35
# 3767          5           35
# ...         ...          ...
# 3938          1            7
# 3935          1            6
# 3944          1            6
# 1609          5            5
# 148           5            3
#
# [3945 rows x 2 columns]

# %%
products_new.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of       StockCode  Description
# 2812          5           35
# 3520          5           35
# 3603          5           35
# 3766          5           35
# 3767          5           35
# ...         ...          ...
# 3938          1            7
# 3935          1            6
# 3944          1            6
# 1609          5            5
# 148           5            3
#
# [3945 rows x 2 columns]>

# %% [markdown]
# 3.2.5 Writing user-defined functions

# %%
# Write your first user-defined function.

def calculator(a, b):
    print('Addition', a+b)
    print('Subtract', a-b)
    print('Multiplication', a*b)
    print('Division', a/b)
    return;

calculator(25, 5)
# Out:
# Addition 30
# Subtract 20
# Multiplication 125
# Division 5.0

# %%
calculator(250,315)
# Out:
# Addition 565
# Subtract -65
# Multiplication 78750
# Division 0.7936507936507936

# %%
# Import Pandas.
import pandas as pd

# Read the CSV file from the current working directory.
products = pd.read_csv('products.csv')

# View the DataFrame.
products.shape
# Out:
# (3945, 2)

# %%
products
# Out:
#          StockCode                        Description
# 0            10002         INFLATABLE POLITICAL GLOBE
# 1            10080           GROOVY CACTUS INFLATABLE
# 2            10120                       DOGGY RUBBER
# 3           10123C               HEARTS WRAPPING TAPE
# 4           10124A        SPOTS ON RED BOOKCOVER TAPE
# ...            ...                                ...
# 3940  gift_0001_20  Dotcomgiftshop Gift Voucher £20.0
# 3941  gift_0001_30  Dotcomgiftshop Gift Voucher £30.0
# 3942  gift_0001_40  Dotcomgiftshop Gift Voucher £40.0
# 3943  gift_0001_50  Dotcomgiftshop Gift Voucher £50.0
# 3944             m                             Manual
#
# [3945 rows x 2 columns]

# %%
# Create an user-defined function
def contains_glass(x):
    """ does the product contain glass? """
    y = x.lower()
    return "glass" in y

# %%
contains_glass("glasstower")
# Out:
# True

# %%
contains_glass("tower")
# Out:
# False

# %%
# Use the apply() function.
fc = products["Description"].apply(contains_glass)

# View the DataFrame.
print(fc)

# Filter the DataFrame.
products[fc]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3940    False
# 3941    False
# 3942    False
# 3943    False
# 3944    False
# Name: Description, Length: 3945, dtype: bool
#      StockCode                    Description
# 106     17129F         BLUE GLASS GEMS IN BAG
# 220      20798          CLEAR MILKSHAKE GLASS
# 221      20801   LARGE PINK GLASS SUNDAE DISH
# 222      20802  SMALL GLASS SUNDAE DISH CLEAR
# 223      20803   SMALL PINK GLASS SUNDAE DISH
# ...        ...                            ...
# 3866    90199D  5 STRAND GLASS NECKLACE AMBER
# 3886    90209A  PURPLE ENAMEL+GLASS HAIR COMB
# 3887    90209B   GREEN ENAMEL+GLASS HAIR COMB
# 3888    90209C    PINK ENAMEL+GLASS HAIR COMB
# 3927  DCGS0003            BOXED GLASS ASHTRAY
#
# [171 rows x 2 columns]

# %%
# Write a lambda function to get the same result as with the user-defined function.
products[products['Description'].apply(lambda x:
                                     "glass" in x.lower())]
# Out:
#      StockCode                    Description
# 106     17129F         BLUE GLASS GEMS IN BAG
# 220      20798          CLEAR MILKSHAKE GLASS
# 221      20801   LARGE PINK GLASS SUNDAE DISH
# 222      20802  SMALL GLASS SUNDAE DISH CLEAR
# 223      20803   SMALL PINK GLASS SUNDAE DISH
# ...        ...                            ...
# 3866    90199D  5 STRAND GLASS NECKLACE AMBER
# 3886    90209A  PURPLE ENAMEL+GLASS HAIR COMB
# 3887    90209B   GREEN ENAMEL+GLASS HAIR COMB
# 3888    90209C    PINK ENAMEL+GLASS HAIR COMB
# 3927  DCGS0003            BOXED GLASS ASHTRAY
#
# [171 rows x 2 columns]

# %%
# Investigate with only a Series.
products['Description'].apply(lambda x: "glass" in x.lower())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3940    False
# 3941    False
# 3942    False
# 3943    False
# 3944    False
# Name: Description, Length: 3945, dtype: bool

# %%
# Create the user-defined function
def contains_Fire(x):
    """ does the product contain Fire? """
    y = x.lower()
    return "Fire" in y

# %%
contains_Fire("Wire")
# Out:
# False

# %% [markdown]
# ### Practical activities

# %% [markdown]
# ### 3.1.5 Practical activity: Create and merge the DataFrames

# %%
import pandas as pd

# %%
movies_merge = pd.read_excel('movies_merge.xlsx')
ott_merge = pd.read_csv('ott_merge.csv')

# %%
print(movies_merge.shape)
print(movies_merge.head)
print(movies_merge.dtypes)
# Out:
# (16744, 11)
# <bound method NDFrame.head of           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
print(ott_merge.shape)
print(ott_merge.head)
print(ott_merge.dtypes)
# Out:
# (16744, 5)
# <bound method NDFrame.head of           ID  Netflix  Hulu  Prime Video  Disney+
# 0          1        0     0            1        0
# 1          2        0     1            0        0
# 2          3        0     0            1        0
# 3          4        1     0            0        0
# 4          5        0     0            1        0
# ...      ...      ...   ...          ...      ...
# 16739  16740        0     0            1        0
# 16740  16741        0     0            1        0
# 16741  16742        0     0            1        0
# 16742  16743        0     0            1        0
# 16743  16744        1     0            0        0
#
# [16744 rows x 5 columns]>
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object

# %%
movies_ott_merge = pd.merge(movies_merge,ott_merge, how = 'inner', on = 'ID')

# %%
movies_ott_merge
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
movies_ott_merge2 = pd.merge(movies_merge,ott_merge, how = 'left', on = 'ID')

# %%
movies_ott_merge2
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
movies_ott_concat = pd.concat([movies_merge, ott_merge], axis = 1)

# %%
movies_ott_concat
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
print(movies_ott_merge.head)
print(movies_ott_merge.shape)
print(movies_ott_concat.head)
print(movies_ott_concat.shape)
# Out:
# <bound method NDFrame.head of           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
print(movies_ott_merge.dtypes)
print(movies_ott_concat.dtypes)
# Out:
# ID                   int64
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# Netflix              int64
# Hulu                 int64
# Prime Video          int64
# Disney+              int64
# dtype: object
# ID                   int64
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# ID                   int64
# Netflix              int64
# Hulu                 int64
# Prime Video          int64
# Disney+              int64
# dtype: object

# %% [markdown]
# ### 3.1.9 Practical activity: Use groupby() and aggregate() functions

# %% [markdown]
# ### Working with Mandisa movies database:
#
# ### - How many films from each year (released from 2012 to the present) were watched on Netflix?
# ### - What is the average runtime of movies released each year?
# ### - What are the best and worst reviews movies received on Rotten Tomatoes?

# %%
# Determine the average runtime of movies released since 2012.

import pandas as pd

mo_gpby = movies_ott_merge.groupby("Year")["Netflix"].count().reset_index()
mo_gpby[mo_gpby['Year']>=2012]
# Out:
#      Year  Netflix
# 100  2012      843
# 101  2013      964
# 102  2014      986
# 103  2015     1065
# 104  2016     1206
# 105  2017     1401
# 106  2018     1285
# 107  2019      689
# 108  2020      147

# %%
mo_gpby_jc = movies_ott_merge.groupby(["Year"])["Netflix"].agg('count').reset_index()
mo_gpby_jc[mo_gpby_jc["Year"]>=2012]
# Out:
#      Year  Netflix
# 100  2012      843
# 101  2013      964
# 102  2014      986
# 103  2015     1065
# 104  2016     1206
# 105  2017     1401
# 106  2018     1285
# 107  2019      689
# 108  2020      147

# %%
# Determine the average runtime of movies released since 2012.

mo_gpby_jc = movies_ott_merge.groupby(["Year"])["Runtime"].agg('mean').reset_index()
mo_gpby_jc[mo_gpby_jc["Year"]>=2012]
# Out:
#      Year    Runtime
# 100  2012  90.511714
# 101  2013  91.545940
# 102  2014  92.995763
# 103  2015  92.914646
# 104  2016  93.992140
# 105  2017  94.460961
# 106  2018  94.635678
# 107  2019  93.410413
# 108  2020  93.976562

# %%
# Determine what was the maximum and minimum review received by Rotten Tomatoes for any movie per year since 2012?

mo_gpby_jc = movies_ott_merge.groupby(["Year"])["Rotten Tomatoes"].agg(['min','max']).reset_index()
mo_gpby_jc[mo_gpby_jc["Year"]>=2012]
# Out:
#      Year   min  max
# 100  2012  0.04  1.0
# 101  2013  0.02  1.0
# 102  2014  0.05  1.0
# 103  2015  0.05  1.0
# 104  2016  0.02  1.0
# 105  2017  0.04  1.0
# 106  2018  0.06  1.0
# 107  2019  0.05  1.0
# 108  2020  0.06  1.0

# %% [markdown]
# ### 3.1.12 Practical activity: Reshaping a DataFrame

# %% [markdown]
# ### Determine the film release date and content rating

# %%
import pandas as pd

# %%
movies_merge = pd.read_excel('movies_merge.xlsx')
ott_merge = pd.read_csv('ott_merge.csv')

movies_ott_merge = pd.merge(movies_merge,ott_merge, how = 'inner', on = 'ID')

movies_ott_merge
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %%
# Pivot the amerged DataFrame.

movies_rating = movies_ott_merge.pivot(index='Title', columns='Age', values='Year')

# %%
movies_rating
# Out:
# Age                                NaN     13+  16+     18+      7+  all
# Title
# Inception                          NaN  2010.0  NaN     NaN     NaN  NaN
# The Matrix                         NaN     NaN  NaN  1999.0     NaN  NaN
# Avengers: Infinity War             NaN  2018.0  NaN     NaN     NaN  NaN
# Back to the Future                 NaN     NaN  NaN     NaN  1985.0  NaN
# The Good, the Bad and the Ugly     NaN     NaN  NaN  1966.0     NaN  NaN
# ...                                ...     ...  ...     ...     ...  ...
# The Ghosts of Buxley Hall       1980.0     NaN  NaN     NaN     NaN  NaN
# The Poof Point                     NaN     NaN  NaN     NaN  2001.0  NaN
# Sharks of Lost Island           2013.0     NaN  NaN     NaN     NaN  NaN
# Man Among Cheetahs              2017.0     NaN  NaN     NaN     NaN  NaN
# In Beaver Valley                1950.0     NaN  NaN     NaN     NaN  NaN
#
# [16744 rows x 6 columns]

# %% [markdown]
# ### Determine the title of movies, the directors, and genres by content rating.

# %%
movies_rating2 = movies_ott_merge.pivot(index='Title', columns='Age', values=['Directors', 'Genres'])

# %%
movies_rating2
# Out:
#                                            Directors                           \
# Age                                              NaN                      13+
# Title
# Inception                                        NaN        Christopher Nolan
# The Matrix                                       NaN                      NaN
# Avengers: Infinity War                           NaN  Anthony Russo,Joe Russo
# Back to the Future                               NaN                      NaN
# The Good, the Bad and the Ugly                   NaN                      NaN
# ...                                              ...                      ...
# The Ghosts of Buxley Hall               Bruce Bilson                      NaN
# The Poof Point                                   NaN                      NaN
# Sharks of Lost Island                   Neil Gelinas                      NaN
# Man Among Cheetahs              Richard Slater-Jones                      NaN
# ...

# %% [markdown]
# ### Determine the title of movies, the released year, and language by content rating

# %%
movies_rating3 = movies_ott_merge.pivot(index='Title', columns='Age', values=['Year', 'Language'])

# %%
movies_rating3
# Out:
#                                 Year                             Language  \
# Age                              NaN   13+  16+   18+    7+  all      NaN
# Title
# Inception                        NaN  2010  NaN   NaN   NaN  NaN      NaN
# The Matrix                       NaN   NaN  NaN  1999   NaN  NaN      NaN
# Avengers: Infinity War           NaN  2018  NaN   NaN   NaN  NaN      NaN
# Back to the Future               NaN   NaN  NaN   NaN  1985  NaN      NaN
# The Good, the Bad and the Ugly   NaN   NaN  NaN  1966   NaN  NaN      NaN
# ...                              ...   ...  ...   ...   ...  ...      ...
# The Ghosts of Buxley Hall       1980   NaN  NaN   NaN   NaN  NaN  English
# The Poof Point                   NaN   NaN  NaN   NaN  2001  NaN      NaN
# Sharks of Lost Island           2013   NaN  NaN   NaN   NaN  NaN  English
# Man Among Cheetahs              2017   NaN  NaN   NaN   NaN  NaN  English
# In Beaver Valley                1950   NaN  NaN   NaN   NaN  NaN  English
# ...

# %% [markdown]
# ### Determine the Netflix screened movies based on language, runtime, and country.

# %%
movies_rating4 = movies_ott_merge.pivot(index='Title', columns='Netflix', values=['Runtime', 'Language', 'Country'])

# %%
movies_rating4
# Out:
#                                Runtime                        Language  \
# Netflix                              0      1                        0
# Title
# Inception                        148.0    NaN  English,Japanese,French
# The Matrix                       136.0    NaN                  English
# Avengers: Infinity War           149.0    NaN                  English
# Back to the Future                 NaN  116.0                      NaN
# The Good, the Bad and the Ugly   161.0    NaN                  Italian
# ...                                ...    ...                      ...
# The Ghosts of Buxley Hall        120.0    NaN                  English
# The Poof Point                    90.0    NaN                  English
# Sharks of Lost Island              NaN    NaN                  English
# Man Among Cheetahs                 NaN    NaN                  English
# In Beaver Valley                   NaN   32.0                      NaN
#
# ...

# %% [markdown]
# ### Determine the title of movies, specified language, potential runtime, and genres by content rating.

# %%
movies_rating5 = movies_ott_merge.pivot(index='Title', columns='Age', values=['Runtime', 'Language', 'Genres'])

# %%
movies_rating5
# Out:
#                                Runtime                                 \
# Age                                NaN    13+  16+    18+     7+  all
# Title
# Inception                          NaN  148.0  NaN    NaN    NaN  NaN
# The Matrix                         NaN    NaN  NaN  136.0    NaN  NaN
# Avengers: Infinity War             NaN  149.0  NaN    NaN    NaN  NaN
# Back to the Future                 NaN    NaN  NaN    NaN  116.0  NaN
# The Good, the Bad and the Ugly     NaN    NaN  NaN  161.0    NaN  NaN
# ...                                ...    ...  ...    ...    ...  ...
# The Ghosts of Buxley Hall        120.0    NaN  NaN    NaN    NaN  NaN
# The Poof Point                     NaN    NaN  NaN    NaN   90.0  NaN
# Sharks of Lost Island              NaN    NaN  NaN    NaN    NaN  NaN
# Man Among Cheetahs                 NaN    NaN  NaN    NaN    NaN  NaN
# In Beaver Valley                  32.0    NaN  NaN    NaN    NaN  NaN
#
# ...

# %% [markdown]
# ### 3.2.4 Practical activity: apply() function

# %% [markdown]
# ### What is the effect of adding 60 seconds (1 minute) to each movie?

# %%
import pandas as pd
import numpy as np

# Create new pandas DataFrame.
mov_ott_runtime = movies_ott_merge[['ID', 'Runtime','Genres']]
mov_ott_runtime
# Out:
#           ID  Runtime                            Genres
# 0          1    148.0  Action,Adventure,Sci-Fi,Thriller
# 1          2    136.0                     Action,Sci-Fi
# 2          3    149.0           Action,Adventure,Sci-Fi
# 3          4    116.0           Adventure,Comedy,Sci-Fi
# 4          5    161.0                           Western
# ...      ...      ...                               ...
# 16739  16740    120.0      Comedy,Family,Fantasy,Horror
# 16740  16741     90.0              Comedy,Family,Sci-Fi
# 16741  16742      NaN                       Documentary
# 16742  16743      NaN                       Documentary
# 16743  16744     32.0          Documentary,Short,Family
#
# [16744 rows x 3 columns]

# %%
mov_ott_runtime['Runtime'].add(1)
# Out:
# 0        149.0
# 1        137.0
# 2        150.0
# 3        117.0
# 4        162.0
#          ...
# 16739    121.0
# 16740     91.0
# 16741      NaN
# 16742      NaN
# 16743     33.0
# Name: Runtime, Length: 16744, dtype: float64

# %%
mov_ott_runtime
# Out:
#           ID  Runtime                            Genres
# 0          1    148.0  Action,Adventure,Sci-Fi,Thriller
# 1          2    136.0                     Action,Sci-Fi
# 2          3    149.0           Action,Adventure,Sci-Fi
# 3          4    116.0           Adventure,Comedy,Sci-Fi
# 4          5    161.0                           Western
# ...      ...      ...                               ...
# 16739  16740    120.0      Comedy,Family,Fantasy,Horror
# 16740  16741     90.0              Comedy,Family,Sci-Fi
# 16741  16742      NaN                       Documentary
# 16742  16743      NaN                       Documentary
# 16743  16744     32.0          Documentary,Short,Family
#
# [16744 rows x 3 columns]

# %% [markdown]
# ### Which movies are documentaries?

# %%
# Create a new column with documentaries.

mov_ott_runtime
# Out:
#           ID  Runtime                            Genres          Gen_doc
# 0          1    148.0  Action,Adventure,Sci-Fi,Thriller  Not Documentary
# 1          2    136.0                     Action,Sci-Fi  Not Documentary
# 2          3    149.0           Action,Adventure,Sci-Fi  Not Documentary
# 3          4    116.0           Adventure,Comedy,Sci-Fi  Not Documentary
# 4          5    161.0                           Western  Not Documentary
# ...      ...      ...                               ...              ...
# 16739  16740    120.0      Comedy,Family,Fantasy,Horror  Not Documentary
# 16740  16741     90.0              Comedy,Family,Sci-Fi  Not Documentary
# 16741  16742      NaN                       Documentary      Documentary
# 16742  16743      NaN                       Documentary      Documentary
# 16743  16744     32.0          Documentary,Short,Family      Documentary
#
# [16744 rows x 4 columns]

# %%
# Import Pandas and NumPy.
import pandas as pd
import numpy as np

# Load the excel data using pd.read_excel.
movies = pd.read_excel('movies_merge.xlsx')

# Load the csv data using pd.read_csv.
ott = pd.read_csv('ott_merge.csv')

# Data imported correctly?
print(movies.columns)
print(movies.shape)
print(ott.columns)
print(ott.shape)

# Merge the two DataFrames.
mov_ott = pd.merge(movies, ott, how='left', on = 'ID')

# DataFrames merged correctly?
print(mov_ott.columns)
print(mov_ott.shape)
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')
# (16744, 11)
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')
# (16744, 5)
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime', 'Netflix', 'Hulu',
#        'Prime Video', 'Disney+'],
#       dtype='object')
# (16744, 15)

# %%
# Create new pandas DataFrame.
mov_ott_runtime = mov_ott[['ID', 'Runtime','Genres']]
mov_ott_runtime
# Out:
#           ID  Runtime                            Genres
# 0          1    148.0  Action,Adventure,Sci-Fi,Thriller
# 1          2    136.0                     Action,Sci-Fi
# 2          3    149.0           Action,Adventure,Sci-Fi
# 3          4    116.0           Adventure,Comedy,Sci-Fi
# 4          5    161.0                           Western
# ...      ...      ...                               ...
# 16739  16740    120.0      Comedy,Family,Fantasy,Horror
# 16740  16741     90.0              Comedy,Family,Sci-Fi
# 16741  16742      NaN                       Documentary
# 16742  16743      NaN                       Documentary
# 16743  16744     32.0          Documentary,Short,Family
#
# [16744 rows x 3 columns]

# %%
mov_ott_runtime['Runtime'].add(1)
# Out:
# 0        149.0
# 1        137.0
# 2        150.0
# 3        117.0
# 4        162.0
#          ...
# 16739    121.0
# 16740     91.0
# 16741      NaN
# 16742      NaN
# 16743     33.0
# Name: Runtime, Length: 16744, dtype: float64

# %%
# To understand which movies are documentaries

# Create a new column with documentaries.
mov_ott_runtime['Gen_doc'] = np.where(mov_ott_runtime['Genres'].str.contains('Documentary'),
                                      'Documentary', 'Not Documentary')

# View the DataFrame.
mov_ott_runtime
# Out:
# /var/folders/_k/8h4zfdrd3qgd4kzz6qhbbzyh0000gn/T/ipykernel_58380/2110295281.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_ott_runtime['Gen_doc'] = np.where(mov_ott_runtime['Genres'].str.contains('Documentary'),
#           ID  Runtime                            Genres          Gen_doc
# 0          1    148.0  Action,Adventure,Sci-Fi,Thriller  Not Documentary
# 1          2    136.0                     Action,Sci-Fi  Not Documentary
# 2          3    149.0           Action,Adventure,Sci-Fi  Not Documentary
# 3          4    116.0           Adventure,Comedy,Sci-Fi  Not Documentary
# 4          5    161.0                           Western  Not Documentary
# ...      ...      ...                               ...              ...
# ...

# %%
mov_ott_runtime
# Out:
#           ID  Runtime                            Genres          Gen_doc
# 0          1    148.0  Action,Adventure,Sci-Fi,Thriller  Not Documentary
# 1          2    136.0                     Action,Sci-Fi  Not Documentary
# 2          3    149.0           Action,Adventure,Sci-Fi  Not Documentary
# 3          4    116.0           Adventure,Comedy,Sci-Fi  Not Documentary
# 4          5    161.0                           Western  Not Documentary
# ...      ...      ...                               ...              ...
# 16739  16740    120.0      Comedy,Family,Fantasy,Horror  Not Documentary
# 16740  16741     90.0              Comedy,Family,Sci-Fi  Not Documentary
# 16741  16742      NaN                       Documentary      Documentary
# 16742  16743      NaN                       Documentary      Documentary
# 16743  16744     32.0          Documentary,Short,Family      Documentary
#
# [16744 rows x 4 columns]

# %%
# Inside of the parenthesis, there are three inputs:

# condition
# output-if-true
# output-if-false

# %% [markdown]
# ### 3.2.6 Practical activity: Write and apply user-defined functions

# %% [markdown]
# ### What is the average rating per movie?

# %%
mov_ott_ratings = mov_ott[['ID', 'IMDb','Rotten Tomatoes']]

# %%
mov_ott_ratings
# Out:
#           ID  IMDb  Rotten Tomatoes
# 0          1   8.8             0.87
# 1          2   8.7             0.87
# 2          3   8.5             0.84
# 3          4   8.5             0.96
# 4          5   8.8             0.97
# ...      ...   ...              ...
# 16739  16740   6.2              NaN
# 16740  16741   4.7              NaN
# 16741  16742   5.7              NaN
# 16742  16743   6.6              NaN
# 16743  16744   NaN              NaN
#
# [16744 rows x 3 columns]

# %%
# 3) For an entire DataFrame using Pandas: df.fillna(0)
# df[['DataFrame Column']] = df[['DataFrame Column']].fillna(0)

mov_ott_ratings[['IMDb', 'Rotten Tomatoes']] = mov_ott_ratings[['IMDb', 'Rotten Tomatoes']].fillna(0)

# %%
mov_ott_ratings
# Out:
#           ID  IMDb  Rotten Tomatoes
# 0          1   8.8             0.87
# 1          2   8.7             0.87
# 2          3   8.5             0.84
# 3          4   8.5             0.96
# 4          5   8.8             0.97
# ...      ...   ...              ...
# 16739  16740   6.2             0.00
# 16740  16741   4.7             0.00
# 16741  16742   5.7             0.00
# 16742  16743   6.6             0.00
# 16743  16744   0.0             0.00
#
# [16744 rows x 3 columns]

# %%
## Create an user-defined function
#def contains_glass(x):
#    """ does the product contain glass? """
#    y = x.lower()
#    return "glass" in y

def avg_col2(df1,df2):
    avg_col2 = ((df1/10) + df2)/2
    return avg_col2

# %%
# Create a new column with results.
mov_ott_ratings['Ratings'] = avg_col2(mov_ott_ratings['IMDb'], mov_ott_ratings['Rotten Tomatoes'])
mov_ott_ratings
# Out:
# /var/folders/_k/8h4zfdrd3qgd4kzz6qhbbzyh0000gn/T/ipykernel_58380/3041839005.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mov_ott_ratings['Ratings'] = avg_col2(mov_ott_ratings['IMDb'], mov_ott_ratings['Rotten Tomatoes'])
#           ID  IMDb  Rotten Tomatoes  Ratings
# 0          1   8.8             0.87    0.875
# 1          2   8.7             0.87    0.870
# 2          3   8.5             0.84    0.845
# 3          4   8.5             0.96    0.905
# 4          5   8.8             0.97    0.925
# ...      ...   ...              ...      ...
# 16739  16740   6.2             0.00    0.310
# 16740  16741   4.7             0.00    0.235
# 16741  16742   5.7             0.00    0.285
# 16742  16743   6.6             0.00    0.330
# ...

# %% [markdown]
# ### How many movies were released per content rating?

# %%
# Defining the function:
def cat_cnt(df1):
    print(df1.value_counts())
    return

# %%
df = mov_ott['Age'].astype('category')

# %%
df
# Out:
# 0        13+
# 1        18+
# 2        13+
# 3         7+
# 4        18+
#         ...
# 16739    NaN
# 16740     7+
# 16741    NaN
# 16742    NaN
# 16743    NaN
# Name: Age, Length: 16744, dtype: category
# Categories (5, object): ['13+', '16+', '18+', '7+', 'all']

# %%
cat_cnt(df)
# Out:
# 18+    3474
# 7+     1462
# 13+    1255
# all     843
# 16+     320
# Name: Age, dtype: int64

# %% [markdown]
# ### How many movies were released per year?

# %%
df2 = mov_ott['Year'].astype('category')

# %%
print(cat_cnt(df2))
# Out:
# 2017    1401
# 2018    1285
# 2016    1206
# 2015    1065
# 2014     986
#         ...
# 1916       1
# 1912       1
# 1917       1
# 1924       1
# 1902       1
# Name: Year, Length: 109, dtype: int64
# None

# %% [markdown]
# ### QUIZ

# %%
func = lambda x: return x

print(func(2))
# Out:
#   File "/var/folders/_k/8h4zfdrd3qgd4kzz6qhbbzyh0000gn/T/ipykernel_58380/556241935.py", line 1
#     func = lambda x: return x
#                      ^
# SyntaxError: invalid syntax

# %%
func = lambda x: x

print(func(2))
# Out:
# 2

# %%
t = lambda x: (x + 3) * 5 / 2

t(9)
# Out:
# 30.0

# %%
numbers=[1, 2, 3]

# %%
list(filter(lambda x: x % 2 == 0, numbers))
# Out:
# [2]

# %%
list(filter(lambda x: 2, numbers))
# Out:
# [1, 2, 3]

# %%
list(filter(lambda x,y: x>1, number)
# Out:
#   File "/var/folders/_k/8h4zfdrd3qgd4kzz6qhbbzyh0000gn/T/ipykernel_58380/3388341376.py", line 1
#     list(filter(lambda x,y: x>1, number)
#                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
list(filter(lambda x: x > 1, numbers))
# Out:
# [2, 3]
